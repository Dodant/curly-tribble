# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from IPython.display import Image

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

data = pd.read_csv('dataset/price_data_tr.csv')

# %%
# data.columns
# 'id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
# 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15'
data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      1310440590  20150413T000000  440000.0         3       2.50
# 1      1437580480  20140918T000000  994000.0         5       3.25
# 2      7617500075  20140721T000000  427000.0         3       1.75
# 3      8122100130  20140618T000000  415000.0         3       1.75
# 4      4476400275  20150114T000000  335000.0         3       1.75
# ...           ...              ...       ...       ...        ...
# 12963  1773100604  20140721T000000  346000.0         3       3.25
# 12964  6403510090  20141111T000000  437500.0         4       2.50
# 12965  2124049160  20150416T000000  440000.0         6       3.00
# 12966  1310960190  20141021T000000  263000.0         3       1.75
# 12967  3876312490  20150414T000000  435000.0         4       2.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             2290      6302     2.0           0     0  ...      9
# ...

# %%
from scipy import stats
from scipy.stats import norm

sns.distplot(data['price'],fit = norm)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.distplot(np.log(data['price']), fit = norm)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
# data['date'] = pd.to_datetime(data['date']) # str에서 datetime으로 타입 변경
# data

# %%
corr = data.corr(method='pearson')
corr.iloc[:, 1]
# Out:
# id              -0.013029
# price            1.000000
# bedrooms         0.322938
# bathrooms        0.525247
# sqft_living      0.697376
# sqft_lot         0.080147
# floors           0.254591
# waterfront       0.277248
# view             0.393101
# condition        0.032984
# grade            0.666064
# sqft_above       0.603758
# sqft_basement    0.320450
# yr_built         0.055129
# yr_renovated     0.110779
# zipcode         -0.049526
# lat              0.306516
# long             0.017529
# sqft_living15    0.587954
# sqft_lot15       0.076897
# Name: price, dtype: float64

# %%
# data['price'] = np.log(data['price'])
data = data.drop([3663,9601,10035,11858,473,4731,8708,6713,8534,4220,155,7585,679,342,5379,1518,4522,12711,4680,10127,2246,3234,6797,12443,11038,3520,11895,1527,8652,3586])
data['price'] = np.log(data['price'])
corr = data.corr(method='pearson')
corr.iloc[:, 1]
# Out:
# id               0.001221
# price            1.000000
# bedrooms         0.352911
# bathrooms        0.538647
# sqft_living      0.684190
# sqft_lot         0.088385
# floors           0.303713
# waterfront       0.171374
# view             0.341215
# condition        0.040514
# grade            0.700433
# sqft_above       0.591307
# sqft_basement    0.307524
# yr_built         0.076951
# yr_renovated     0.098593
# zipcode         -0.028862
# lat              0.450179
# long             0.044136
# sqft_living15    0.615416
# sqft_lot15       0.082726
# Name: price, dtype: float64

# %%
data['yr_max'] = np.maximum(np.array(data.yr_built), np.array(data.yr_renovated))
data = data.drop(['yr_built','yr_renovated'], axis=1)
corr = data.corr(method='pearson')
corr.iloc[:, 1]
# Out:
# id               0.001221
# price            1.000000
# bedrooms         0.352911
# bathrooms        0.538647
# sqft_living      0.684190
# sqft_lot         0.088385
# floors           0.303713
# waterfront       0.171374
# view             0.341215
# condition        0.040514
# grade            0.700433
# sqft_above       0.591307
# sqft_basement    0.307524
# zipcode         -0.028862
# lat              0.450179
# long             0.044136
# sqft_living15    0.615416
# sqft_lot15       0.082726
# yr_max           0.120452
# Name: price, dtype: float64

# %%
data['sqft_lot'] = np.log(data['sqft_lot'])
data['sqft_lot15'] = np.log(data['sqft_lot15'])
corr = data.corr(method='pearson')
corr.iloc[:, 1]
# Out:
# id               0.001369
# price            1.000000
# bedrooms         0.356079
# bathrooms        0.547390
# sqft_living      0.691444
# sqft_lot         0.134617
# floors           0.305246
# waterfront       0.179603
# view             0.346067
# condition        0.038593
# grade            0.705130
# sqft_above       0.600118
# sqft_basement    0.314914
# zipcode         -0.031402
# lat              0.447475
# long             0.042046
# sqft_living15    0.620374
# sqft_lot15       0.119609
# yr_max           0.122833
# Name: price, dtype: float64

# %%
data['zipcode'] = -data['zipcode']
corr = data.corr(method='pearson')
corr.iloc[:, 1]
# Out:
# id               0.001369
# price            1.000000
# bedrooms         0.356079
# bathrooms        0.547390
# sqft_living      0.691444
# sqft_lot         0.134617
# floors           0.305246
# waterfront       0.179603
# view             0.346067
# condition        0.038593
# grade            0.705130
# sqft_above       0.600118
# sqft_basement    0.314914
# zipcode          0.031402
# lat              0.447475
# long             0.042046
# sqft_living15    0.620374
# sqft_lot15       0.119609
# yr_max           0.122833
# Name: price, dtype: float64

# %%
sns.distplot(data['zipcode'], fit=norm)
# Out:
# <AxesSubplot:xlabel='zipcode', ylabel='Density'>

# %%
data['sqft_above'] = np.log(data['sqft_above'])
corr = data.corr(method='pearson')
corr.iloc[:, 1]
# Out:
# id               0.001369
# price            1.000000
# bedrooms         0.356079
# bathrooms        0.547390
# sqft_living      0.691444
# sqft_lot         0.134617
# floors           0.305246
# waterfront       0.179603
# view             0.346067
# condition        0.038593
# grade            0.705130
# sqft_above       0.584686
# sqft_basement    0.314914
# zipcode         -0.031402
# lat              0.447475
# long             0.042046
# sqft_living15    0.620374
# sqft_lot15       0.119609
# yr_max           0.122833
# Name: price, dtype: float64

# %%
# sns.jointplot(data['price'], np.log(data['sqft_basement']))

# %%
data['sqft_basement'] = np.log(data['sqft_basement'])
corr = data.corr(method='pearson')
corr.iloc[:, 1]
# Out:
# /home/dodanto/Documents/curly-tribble/py38/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# id               0.001369
# price            1.000000
# bedrooms         0.356079
# bathrooms        0.547390
# sqft_living      0.691444
# sqft_lot         0.134617
# floors           0.305246
# waterfront       0.179603
# view             0.346067
# condition        0.038593
# grade            0.705130
# sqft_above       0.600118
# sqft_basement    0.311733
# zipcode         -0.031402
# lat              0.447475
# long             0.042046
# sqft_living15    0.608081
# sqft_lot15       0.119609
# yr_max           0.122833
# Name: price, dtype: float64

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
sns.jointplot(data['price'],data['date'])

# %%
data['date'] = data['date'].dt.year

# %%
data['date']
# Out:
# 0        2015
# 1        2014
# 2        2014
# 3        2014
# 4        2015
#          ...
# 12963    2014
# 12964    2014
# 12965    2015
# 12966    2014
# 12967    2015
# Name: date, Length: 12968, dtype: int64

# %%
sns.jointplot(data['price'],data['date'])

# %%
corr = data.corr(method='pearson')
corr.iloc[:, 2]
# Out:
# id               0.001369
# date            -0.011978
# price            1.000000
# bedrooms         0.356079
# bathrooms        0.547390
# sqft_living      0.691444
# sqft_lot         0.134617
# floors           0.305246
# waterfront       0.179603
# view             0.346067
# condition        0.038593
# grade            0.705130
# sqft_above       0.600118
# sqft_basement    0.311733
# zipcode         -0.031402
# lat              0.447475
# long             0.042046
# sqft_living15    0.608081
# sqft_lot15       0.119609
# yr_max           0.122833
# Name: price, dtype: float64
